# %% [markdown]
# # Análise de Dados

# %% [markdown]
# ## Importando base de dados

# %%
import pandas as pd

# %%
dados = pd.read_csv('arquivos/tips.csv')
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# ## Renomeando os campos

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {'total_bill': 'Valor_da_conta', 
            'tip': 'Gorjeta', 
            'dessert': 'Sobremesa', 
            'day': 'Dia_da_semana', 
            'time': 'Hora_do_dia', 
            'size': 'Total_de_pessoas'}

# %%
novo_df = dados.rename(columns = renomear)

# %%
novo_df
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01        No           Sun      Dinner
# 1             10.34     1.66        No           Sun      Dinner
# 2             21.01     3.50        No           Sun      Dinner
# 3             23.68     3.31        No           Sun      Dinner
# 4             24.59     3.61        No           Sun      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92        No           Sat      Dinner
# 240           27.18     2.00       Yes           Sat      Dinner
# 241           22.67     2.00       Yes           Sat      Dinner
# 242           17.82     1.75        No           Sat      Dinner
# 243           18.78     3.00        No          Thur      Dinner
#
#      Total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %%
novo_df.Sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {'No': 'Não', 'Yes': 'Sim'}

# %%
novo_df.Sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: Sobremesa, Length: 244, dtype: object

# %%
novo_df.Sobremesa = novo_df.Sobremesa.map(sim_nao)

# %%
novo_df
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01       Não           Sun      Dinner
# 1             10.34     1.66       Não           Sun      Dinner
# 2             21.01     3.50       Não           Sun      Dinner
# 3             23.68     3.31       Não           Sun      Dinner
# 4             24.59     3.61       Não           Sun      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não           Sat      Dinner
# 240           27.18     2.00       Sim           Sat      Dinner
# 241           22.67     2.00       Sim           Sat      Dinner
# 242           17.82     1.75       Não           Sat      Dinner
# 243           18.78     3.00       Não          Thur      Dinner
#
#      Total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %%
novo_df.Dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {'Sun': 'Domingo', 'Sat': 'Sábado', 'Thur': 'Quinta-feira', 'Fri': 'Sexta-feira'}

# %%
novo_df.Dia_da_semana = novo_df.Dia_da_semana.map(dias)

# %%
novo_df
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Dinner
# 1             10.34     1.66       Não       Domingo      Dinner
# 2             21.01     3.50       Não       Domingo      Dinner
# 3             23.68     3.31       Não       Domingo      Dinner
# 4             24.59     3.61       Não       Domingo      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Dinner
# 240           27.18     2.00       Sim        Sábado      Dinner
# 241           22.67     2.00       Sim        Sábado      Dinner
# 242           17.82     1.75       Não        Sábado      Dinner
# 243           18.78     3.00       Não  Quinta-feira      Dinner
#
#      Total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %%
novo_df.Hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {'Dinner': 'Jantar', 'Lunch': 'Almoço'}

# %%
novo_df.Hora_do_dia = novo_df.Hora_do_dia.map(hora)

# %%
novo_df
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não  Quinta-feira      Jantar
#
#      Total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %%
novo_df.to_csv('arquivos/tips_tratada.csv', index = False)

# %% [markdown]
# ## Gerando Gráficos

# %%
import seaborn as sns
import pandas as pd

# %%
dados = pd.read_csv('arquivos/tips_tratada.csv')

# %%
dados
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não  Quinta-feira      Jantar
#
#      Total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %% [markdown]
# ## Análise 1 - Valor da conta e gorjeta

# %%
novo_df.columns
# Out:
# Index(['Valor_da_conta', 'Gorjeta', 'Sobremesa', 'Dia_da_semana',
#        'Hora_do_dia', 'Total_de_pessoas'],
#       dtype='object')

# %%
grafico1 = sns.scatterplot(x = 'Valor_da_conta', y = 'Gorjeta', data = novo_df)

# %% [markdown]
# #### Visualmente o valor da gorjeta aumenta conforme o valor da conta

# %%
print(f'A base de dados contém {novo_df.shape[0]} registros')
# Out:
# A base de dados contém 244 registros

# %%
novo_df.count()
# Out:
# Valor_da_conta      244
# Gorjeta             244
# Sobremesa           244
# Dia_da_semana       244
# Hora_do_dia         244
# Total_de_pessoas    244
# dtype: int64

# %%
print('A base de dados não possui valores nulos.')
# Out:
# A base de dados não possui valores nulos.

# %% [markdown]
# ## Criando o campo porcentagem

# %%
novo_df['Porcentagem'] = novo_df['Gorjeta'] / novo_df['Valor_da_conta']

# %%
novo_df
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não  Quinta-feira      Jantar
#
#      Total_de_pessoas  Porcentagem
# 0                   2     0.059447
# 1                   3     0.160542
# 2                   3     0.166587
# 3                   2     0.139780
# ...

# %%
novo_df.Porcentagem = novo_df.Porcentagem.round(2)

# %%
novo_df
# Out:
#      Valor_da_conta  Gorjeta Sobremesa Dia_da_semana Hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não  Quinta-feira      Jantar
#
#      Total_de_pessoas  Porcentagem
# 0                   2         0.06
# 1                   3         0.16
# 2                   3         0.17
# 3                   2         0.14
# ...

# %%
grafico2 = sns.scatterplot(x = 'Valor_da_conta', y = 'Porcentagem', data = novo_df)

# %% [markdown]
# #### Visualmente percebe-se que o valor da conta não é proporcional ao valor da gorjeta, e sim que diminui

# %%
novo_df.to_csv('arquivos/tips_tratada.csv', index = False)

# %%
grafico3 = sns.relplot(x = 'Valor_da_conta', y = 'Porcentagem', data = novo_df, kind = 'line')

# %%
grafico4 = sns.lmplot(x = 'Valor_da_conta', y = 'Porcentagem', data = novo_df)

# %% [markdown]
# ## Análise 2 - Sobremesa

# %%
novo_df[novo_df.Sobremesa == 'Sim'].describe().round(2)
# Out:
#        Valor_da_conta  Gorjeta  Total_de_pessoas  Porcentagem
# count           93.00    93.00             93.00        93.00
# mean            20.76     3.01              2.41         0.16
# std              9.83     1.40              0.81         0.09
# min              3.07     1.00              1.00         0.04
# 25%             13.42     2.00              2.00         0.11
# 50%             17.92     3.00              2.00         0.15
# 75%             26.86     3.68              3.00         0.20
# max             50.81    10.00              5.00         0.71

# %%
novo_df[novo_df.Sobremesa == 'Não'].describe().round(2)
# Out:
#        Valor_da_conta  Gorjeta  Total_de_pessoas  Porcentagem
# count          151.00   151.00            151.00       151.00
# mean            19.19     2.99              2.67         0.16
# std              8.26     1.38              1.02         0.04
# min              7.25     1.00              1.00         0.06
# 25%             13.32     2.00              2.00         0.14
# 50%             17.59     2.74              2.00         0.16
# 75%             22.76     3.50              3.00         0.18
# max             48.33     9.00              6.00         0.29

# %%
grafico5 = sns.catplot(x = 'Sobremesa', y = 'Gorjeta', data = novo_df)

# %%
grafico6 = sns.relplot(x = 'Valor_da_conta', y = 'Gorjeta', hue = 'Sobremesa', data = novo_df)

# %%
grafico7 = sns.relplot(x = 'Valor_da_conta', y = 'Gorjeta', hue = 'Sobremesa', col = 'Sobremesa', data = novo_df)

# %%
grafico8 = sns.lmplot(x = 'Valor_da_conta', y = 'Gorjeta', col = 'Sobremesa', hue = 'Sobremesa', data = novo_df)

# %%
grafico9 = sns.lmplot(x = 'Valor_da_conta', y = 'Porcentagem', col = 'Sobremesa', hue = 'Sobremesa', data = novo_df)

# %%
grafico10 = sns.relplot(x = 'Valor_da_conta', y = 'Porcentagem', col = 'Sobremesa', hue = 'Sobremesa', kind = 'line', data = novo_df)

# %% [markdown]
# #### Visualmente existe uma diferença no valor da gorjeta daqueles que pediram sobremesa.

# %% [markdown]
# ## Teste de Hipótese

# %% [markdown]
# #### Hipótese nula -> A distribuição da taxa da gorjeta é a mesa nos dois grupos
#
# #### Hipótese alternativa -> A distribuição da taxa da gorjeta não é a mesma nos dois grupos

# %%
from scipy.stats import ranksums

# %%
sobremesa = novo_df.query("Sobremesa == 'Sim'").Porcentagem

# %%
sem_sobremesa = novo_df.query("Sobremesa == 'Não'").Porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print(f'O valor do pvalue é {r.pvalue}.')
# Out:
# O valor do pvalue é 0.5266635660124415.

# %% [markdown]
# #### Hipótese nula -> A distribuição da taxa da gorjeta é a mesa nos dois grupos

# %% [markdown]
# ## Análise 3 - Dias da Semana

# %%
novo_df.Dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta-feira', 'Sexta-feira'], dtype=object)

# %%
grafico11 = sns.catplot(x = 'Dia_da_semana', y = 'Valor_da_conta', data = novo_df)

# %%
grafico12 = sns.relplot(x = 'Valor_da_conta', y = 'Gorjeta', hue = 'Dia_da_semana', data = novo_df)

# %%
grafico13 = sns.relplot(x = 'Valor_da_conta', y = 'Porcentagem', hue = 'Dia_da_semana', data = novo_df)

# %%
grafico14 = sns.relplot(x = 'Valor_da_conta', y = 'Gorjeta', hue = 'Dia_da_semana', col = 'Dia_da_semana', data = novo_df)

# %%
grafico15 = sns.relplot(x = 'Valor_da_conta', y = 'Porcentagem', hue = 'Dia_da_semana', col = 'Dia_da_semana', data = novo_df)

# %%
grafico16 = sns.lmplot(x = 'Valor_da_conta', y = 'Porcentagem', hue = 'Dia_da_semana', col = 'Dia_da_semana', data = novo_df)

# %%
media_gorjetas = novo_df.Gorjeta.mean()

# %%
print(f'A média geral das gorjetas é de {media_gorjetas}.')
# Out:
# A média geral das gorjetas é de 2.9982786885245902.

# %%
novo_df.groupby(['Dia_da_semana']).mean().round(3)[['Valor_da_conta', 'Gorjeta', 'Porcentagem']]
# Out:
#                Valor_da_conta  Gorjeta  Porcentagem
# Dia_da_semana
# Domingo                21.410    3.255        0.167
# Quinta-feira           17.683    2.771        0.161
# Sexta-feira            17.152    2.735        0.169
# Sábado                 20.441    2.993        0.154

# %%
print('Frequência dos dias')
novo_df.Dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado          87
# Domingo         76
# Quinta-feira    62
# Sexta-feira     19
# Name: Dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de Hipótese

# %% [markdown]
# #### Hipótese nula -> A distribuição do valor da conta é igual no sábado e no domingo
#
# #### Hipóstese alternativa -> A distribuição do valor da conta não é igual no sábado e no domingo

# %%
conta_domingo = novo_df.query("Dia_da_semana == 'Domingo'").Valor_da_conta

# %%
conta_sabado = novo_df.query("Dia_da_semana == 'Sábado'").Valor_da_conta

# %%
r1 = ranksums(conta_domingo, conta_sabado)

# %%
print(f'O valor do pvalue é {r1.pvalue}.')
# Out:
# O valor do pvalue é 0.3576728477868443.

# %% [markdown]
# #### Hipótese nula -> A distribuição do valor da conta é igual no sábado e no domingo

# %% [markdown]
# ## Análise 4 - Hora do Dia

# %%
grafico17 = sns.catplot(x = 'Hora_do_dia', y = 'Valor_da_conta', data = novo_df)

# %%
grafico18 = grafico18 = sns.catplot(x = 'Hora_do_dia', y = 'Valor_da_conta', kind = 'swarm', data = novo_df)

# %%
grafico19 = sns.violinplot(x = 'Hora_do_dia', y = 'Valor_da_conta', data = novo_df)

# %%
grafico20 = sns.boxplot(x = 'Hora_do_dia', y = 'Valor_da_conta', data = novo_df)

# %%
almoco = novo_df.query("Hora_do_dia == 'Almoço'").Valor_da_conta

# %%
grafico21 = sns.displot(almoco, kde = True)

# %%
jantar = novo_df.query("Hora_do_dia == 'Jantar'").Valor_da_conta

# %%
grafico22 = sns.displot(jantar, kde = True)

# %%
novo_df.groupby(['Hora_do_dia']).mean().round(2)[['Valor_da_conta', 'Gorjeta', 'Porcentagem']]
# Out:
#              Valor_da_conta  Gorjeta  Porcentagem
# Hora_do_dia
# Almoço                17.17     2.73         0.16
# Jantar                20.80     3.10         0.16

# %% [markdown]
# ## Teste de Hipótese

# %% [markdown]
# #### Hipótese nula -> A distribuição do valor da conta é igual no jantar e no almoço
#
# #### Hipótese alternativa -> A distribuição do valor não é igual no jantar e no almoço

# %%
r3 = ranksums(jantar, almoco)

# %%
print(f'O valor do pvalue é {r3.pvalue}.')
# Out:
# O valor do pvalue é 0.0011791039723641672.

# %%
porcentagem_almoco = novo_df.query("Hora_do_dia == 'Almoço'").Porcentagem

# %%
porcentagem_jantar = novo_df.query("Hora_do_dia == 'Jantar'").Porcentagem

# %%
r4 = ranksums(porcentagem_almoco, porcentagem_jantar)

# %%
print(f'O valor do pvalue da porcentagem é {r4.pvalue}.')
# Out:
# O valor do pvalue da porcentagem é 0.2602493995587126.

# %% [markdown]
# #### Hipótese nula -> A distribuição da taxa da gorjeta é igual no jantar e no almoço
